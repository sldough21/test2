# %%
# a test file to then commit to the 'test' repository in Githib

# %%
from astropy.io import fits
import numpy as np
from matplotlib import pyplot as plt

# %%
path = "/Users/seandougherty/Documents/NU_Astronomy/simple-git-demo/"

# %%
spectrum = fits.open(path+'spSpec-51788-0386-086.fit')
spec = spectrum[0].data.copy()

# %%
spec.shape
# Out:
# (5, 3860)

# %%
spec
# Out:
# array([[ 2.5126199e+02,  2.5120300e+02,  2.5114400e+02, ...,
#          7.8297302e+01,  7.8297997e+01,  7.8298798e+01],
#        [-2.2858978e+01, -2.2857605e+01, -2.2846603e+01, ...,
#         -6.6149902e-01, -6.4996338e-01, -6.3890839e-01],
#        [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#        [ 1.6777216e+07,  1.6777216e+07,  1.6777216e+07, ...,
#          1.6777216e+07,  1.6777216e+07,  1.6777216e+07],
#        [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00]], dtype=float32)

# %%
lmbda = list(range(3860))

# %%
plt.plot(lmbda,spec[0])
